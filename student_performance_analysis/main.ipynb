# %%
import sys
# !{sys.executable} -m pip install openvino scikit-learn-intelex
# Out:
# 'c:\Users\Ivan' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %%
import openvino as ov
from sklearnex import patch_sklearn

# 1. Vérification OpenVINO (iGPU)
core = ov.Core()
devices = core.available_devices
print(f"✅ Appareils détectés par OpenVINO : {devices}")

# 2. Vérification Accélération ML (Scikit-learn)
try:
    patch_sklearn()
    print("✅ Accélération Intel pour Scikit-learn activée !")
except Exception as e:
    print("❌ Erreur d'activation ML :", e)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import openvino as ov
#       2 from sklearnex import patch_sklearn
#       4 # 1. Vérification OpenVINO (iGPU)
#
# ModuleNotFoundError: No module named 'openvino'
