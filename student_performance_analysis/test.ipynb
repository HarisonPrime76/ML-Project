# %%
import openvino as ov
from sklearnex import patch_sklearn
import sys

# Activation de l'accélération Intel
patch_sklearn()

# Vérification du matériel
core = ov.Core()
print(f"✅ Noyau actif : {sys.executable}")
print(f"✅ Matériel détecté : {core.available_devices}")

if 'GPU' in core.available_devices:
    print("🚀 Bravo ! Ton iGPU est prêt pour l'analyse de performance.")
